# %% [markdown]
# ## Initialization Phase + Data Info

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option('display.max_rows', 500)
sns.set_style('whitegrid')

# %%
df = pd.read_csv('malaysia_produce.csv')

# %%
df
# Out:
#      Iso3   StartDate     EndDate  Area Code      Area  Item Code  \
# 0     MYS  01/01/1991  31/12/1991        131  Malaysia        226
# 1     MYS  01/01/1992  31/12/1992        131  Malaysia        226
# 2     MYS  01/01/1993  31/12/1993        131  Malaysia        226
# 3     MYS  01/01/1994  31/12/1994        131  Malaysia        226
# 4     MYS  01/01/1995  31/12/1995        131  Malaysia        226
# ...   ...         ...         ...        ...       ...        ...
# 9923  MYS  01/01/2015  31/12/2015        131  Malaysia       1800
# 9924  MYS  01/01/2016  31/12/2016        131  Malaysia       1800
# 9925  MYS  01/01/2017  31/12/2017        131  Malaysia       1800
# 9926  MYS  01/01/2018  31/12/2018        131  Malaysia       1800
# 9927  MYS  01/01/2019  31/12/2019        131  Malaysia       1800
#
#                           Item  Element Code  \
# 0                   Areca nuts          5539
# 1                   Areca nuts          5539
# 2                   Areca nuts          5539
# 3                   Areca nuts          5539
# 4                   Areca nuts          5539
# ...                        ...           ...
# 9923  Vegetables&Melons, Total          5539
# 9924  Vegetables&Melons, Total          5539
# 9925  Vegetables&Melons, Total          5539
# 9926  Vegetables&Melons, Total          5539
# 9927  Vegetables&Melons, Total          5539
#
#                                      Element  Year Code  Year  Months Code  \
# 0     Producer Price Index (2014-2016 = 100)       1991  1991         7021
# 1     Producer Price Index (2014-2016 = 100)       1992  1992         7021
# 2     Producer Price Index (2014-2016 = 100)       1993  1993         7021
# 3     Producer Price Index (2014-2016 = 100)       1994  1994         7021
# 4     Producer Price Index (2014-2016 = 100)       1995  1995         7021
# ...                                      ...        ...   ...          ...
# 9923  Producer Price Index (2014-2016 = 100)       2015  2015         7021
# 9924  Producer Price Index (2014-2016 = 100)       2016  2016         7021
# 9925  Producer Price Index (2014-2016 = 100)       2017  2017         7021
# 9926  Producer Price Index (2014-2016 = 100)       2018  2018         7021
# 9927  Producer Price Index (2014-2016 = 100)       2019  2019         7021
#
#             Months  Value
# 0     Annual value     43
# 1     Annual value     43
# 2     Annual value     44
# 3     Annual value     45
# 4     Annual value     45
# ...            ...    ...
# 9923  Annual value     97
# 9924  Annual value    101
# 9925  Annual value    105
# 9926  Annual value    104
# 9927  Annual value    102
#
# [9928 rows x 14 columns]
