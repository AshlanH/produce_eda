# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/samh/Downloads/Datasets/records.csv')

# %%
df.drop(columns=['Unit', 'Flag', 'Area Code', 'Months Code', 'Year Code'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9928 entries, 0 to 9927
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Iso3          9928 non-null   object
#  1   StartDate     9928 non-null   object
#  2   EndDate       9928 non-null   object
#  3   Area Code     9928 non-null   int64
#  4   Area          9928 non-null   object
#  5   Item Code     9928 non-null   int64
#  6   Item          9928 non-null   object
#  7   Element Code  9928 non-null   int64
#  8   Element       9928 non-null   object
#  9   Year Code     9928 non-null   int64
#  10  Year          9928 non-null   int64
#  11  Months Code   9928 non-null   int64
#  12  Months        9928 non-null   object
#  13  Value         9928 non-null   float64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 1.1+ MB

# %%
for each in df.columns:
    print(df[each].isna().value_counts()[0])
#df.Item.isna().value_counts()[0]
# Out:
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928
# 9928

# %%
df[df.Element == 'Producer Price (LCU/tonne)'].head(50)
# Out:
#    Iso3   StartDate     EndDate  Area Code      Area  Item Code       Item  \
# 29  MYS  2004-01-01  2004-12-31        131  Malaysia        367  Asparagus
# 30  MYS  2005-01-01  2005-12-31        131  Malaysia        367  Asparagus
# 31  MYS  2006-01-01  2006-12-31        131  Malaysia        367  Asparagus
# 32  MYS  2007-01-01  2007-12-31        131  Malaysia        367  Asparagus
# 33  MYS  2008-01-01  2008-12-31        131  Malaysia        367  Asparagus
# 34  MYS  2009-01-01  2009-12-31        131  Malaysia        367  Asparagus
# 35  MYS  2010-01-01  2010-12-31        131  Malaysia        367  Asparagus
# 36  MYS  2010-01-01  2010-01-31        131  Malaysia        367  Asparagus
# 37  MYS  2010-02-01  2010-02-28        131  Malaysia        367  Asparagus
# 38  MYS  2010-03-01  2010-03-31        131  Malaysia        367  Asparagus
# 39  MYS  2010-04-01  2010-04-30        131  Malaysia        367  Asparagus
# ...

# %%
df[df.Item == 'Meat live weight, buffalo']
# Out:
#      Iso3   StartDate     EndDate  Area Code      Area  Item Code  \
# 3820  MYS  1993-01-01  1993-12-31        131  Malaysia        973
# 3821  MYS  1994-01-01  1994-12-31        131  Malaysia        973
# 3822  MYS  1995-01-01  1995-12-31        131  Malaysia        973
# 3823  MYS  1996-01-01  1996-12-31        131  Malaysia        973
# 3824  MYS  1997-01-01  1997-12-31        131  Malaysia        973
# ...   ...         ...         ...        ...       ...        ...
# 3952  MYS  2015-01-01  2015-12-31        131  Malaysia        973
# 3953  MYS  2016-01-01  2016-12-31        131  Malaysia        973
# 3954  MYS  2017-01-01  2017-12-31        131  Malaysia        973
# 3955  MYS  2018-01-01  2018-12-31        131  Malaysia        973
# 3956  MYS  2019-01-01  2019-12-31        131  Malaysia        973
#
#                            Item  Element Code  \
# 3820  Meat live weight, buffalo          5530
# 3821  Meat live weight, buffalo          5530
# ...

# %%
for each in df[df.Element == 'Producer Price (LCU/tonne)'].Item.unique():
    print(each, ":", df[df.Item == each]['Months'].unique(), '\n')
# Out:
# Asparagus : ['Annual value' 'January' 'February' 'March' 'April' 'May' 'June' 'July'
#  'August' 'September' 'October' 'November' 'December']
#
# Bananas : ['Annual value' 'January' 'February' 'March' 'April' 'May' 'June' 'July'
#  'August' 'September' 'October' 'November' 'December']
#
# Bananas Cavendish : ['Annual value' 'January' 'February' 'March' 'April' 'May' 'June' 'July'
#  'August' 'September' 'October' 'November' 'December']
#
# Bananas non-Cavendish : ['Annual value' 'January' 'February' 'March' 'April' 'May' 'June' 'July'
#  'August' 'September' 'October' 'November' 'December']
#
# Cabbages and other brassicas : ['Annual value' 'January' 'February' 'March' 'April' 'May' 'June' 'July'
#  'August' 'September' 'October' 'November' 'December']
#
# Carrots and turnips : ['Annual value' 'January' 'February' 'March' 'April' 'May' 'June' 'July'
#  'August' 'September' 'October' 'November' 'December']
#
# ...
