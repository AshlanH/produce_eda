# %% [markdown]
# ## Initialization Phase + Data Info

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option('display.max_rows', 500)
sns.set_style('whitegrid')

# %%
df = pd.read_csv('df_LCU_filtered.csv', index_col=0)

# %% [markdown]
# ### Filtered DF_LCU dataframe with accurate entries with ascending years

# %%
df.head()
# Out:
#    index Iso3   StartDate     EndDate      Area  Item Code       Item  \
# 0     29  MYS  01/01/2004  31/12/2004  Malaysia        367  Asparagus
# 1     30  MYS  01/01/2005  31/12/2005  Malaysia        367  Asparagus
# 2     31  MYS  01/01/2006  31/12/2006  Malaysia        367  Asparagus
# 3     32  MYS  01/01/2007  31/12/2007  Malaysia        367  Asparagus
# 4     33  MYS  01/01/2008  31/12/2008  Malaysia        367  Asparagus
#
#                       Element  Year  Months Code        Months  Value
# 0  Producer Price (LCU/tonne)  2004         7021  Annual value   9130
# 1  Producer Price (LCU/tonne)  2005         7021  Annual value  11080
# 2  Producer Price (LCU/tonne)  2006         7021  Annual value  17780
# 3  Producer Price (LCU/tonne)  2007         7021  Annual value  12600
# 4  Producer Price (LCU/tonne)  2008         7021  Annual value  14650

# %%
g = sns.catplot(
    data = df[df.Months == 'Annual value'],
    y = 'Item',
    x = 'Year',
    #aspect = 2.5,
    height = 20,
    kind='box',
    color = '#8cb8b7'
)

g.ax.set_yticklabels(df.Item.unique(), fontsize = 'x-large')
h.ax.set_title('Kernal Density of Produce Indexes to Year', fontdict={'fontsize':18})
g.ax.set_ylabel('Produce', fontsize = 'xx-large')
plt.show()
